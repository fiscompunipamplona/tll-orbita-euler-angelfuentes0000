# %%
from pylab import plot, imshow, show, xlabel, ylabel
from numpy import loadtxt, array, zeros, sqrt, pi, sin
import matplotlib.pyplot as plot

UA = 1.495e11 
GM = 4*pi**2 

#condiciones iniciales 

ro=1 # ua
vo=2*pi # ua/yr
dt=0.02 # delta de t
n=500 # numerop de pasos 
m=1
vel=[]
rad=[]
time=[]
ene =[]
salt=[]
to=[]
THETA=[]
theta=0
for t in range (n):
    a=GM/(ro**2)
    ro= ro+(vo*dt)
    vo=vo+(a*dt)
    E=-(GM*m)/(2*ro)
    theta=theta+(vo/ro)*dt
    rad.append (ro)
    time.append (t*dt)
    ene.append  (E)
    to.append (E)
    THETA.append(theta)
plot.plot  (time,rad) 
plot.show ()
plot.plot (rad,to )
plot.show ()
plot.polar(THETA,rad)
plot.show ()

# %%
from math import pi, sqrt, tan
import matplotlib.pyplot as plt

# %%
# Parameters definition

GM = 4*pi*pi # UA^3 / yr^2

n = 200

v_0 = 2.*pi # UA/yr
r_0 = 1. # UA
the_0 = 0.
dt = 2e-2 # yr

e_n = [] # M* AU^2/yr^2
x_pos = [] # UA
y_pos = [] # UA
r_pos = []
th_pos = []
m = 1. #e-5 # Solar Mass

# Functions definition

def acce_i(r):
    return -GM / (r*r*r)

def ener(r):
    return -(GM*m) / (2*r)

# %%
# Euler method

x_n = r_0
y_n = 0.
vx_n = 0.
vy_n = v_0

r_n = sqrt(x_n*x_n + y_n*y_n)
th = 0.

e_n.append( ener(r_n) )
x_pos.append( x_n )
y_pos.append( x_n )
r_pos.append( r_n )
th_pos.append( th )

for t in range(n):
    tmp_x = x_n
    tmp_y = y_n
    tmp_th = th
    
    
     
    x_n = tmp_x + vx_n*dt
    y_n = tmp_y + vy_n*dt
    
    vx_n = vx_n + tmp_x*acce_i(r_n)*dt
    vy_n = vy_n + tmp_y*acce_i(r_n)*dt
  
    

    r_n = sqrt(x_n*x_n + y_n*y_n)
    th = tmp_th + ( sqrt(vx_n*vx_n + vy_n*vy_n)/r_n ) * dt
        
    e_n.append( ener(r_n) )
    x_pos.append( x_n )
    y_pos.append( y_n )
    r_pos.append( r_n )
    th_pos.append( th )

# %%
plt.plot(x_pos,y_pos)

# %%
plt.polar(th_pos,r_pos)
plt.show()


plt.plot(e_n)
plt.show()
